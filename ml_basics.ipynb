# %%
#!pip install rapidfuzz
import pandas as pd
import numpy as np
import re
from rapidfuzz import fuzz, process
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from scipy.cluster.hierarchy import linkage,dendrogram

# %%
df = pd.read_csv("Fragrance Dataset - COM7022 - [4037].csv")

# %%
df.head()
# Out:
#             brand                                              title  \
# 0            Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1         AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2       Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3  Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4         Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
#
#               type   price priceWithCurrency  available  \
# 0    Eau de Parfum   84.99      US $84.99/ea       10.0
# 1    Eau de Parfum  109.99        US $109.99        8.0
# 2  Eau de Toilette  100.00        US $100.00       10.0
# 3  Eau de Toilette     NaN      US $44.99/ea        2.0
# 4       Fragrances   16.91         US $16.91        NaN
#
#                            availableText   sold                lastUpdated  \
# 0      More than 10 available / 116 sold  116.0  May 24, 2024 10:03:04 PDT
# ...

# %%
# Versions check
print('Python:', sys.version.split()[0])
print('numpy:', np.__version__)
print('pandas:', pd.__version__)
print('matplotlib:', plt.__version__)
print('seaborn:', sns.__version__)
print('scikit-learn:', sklearn.__version__)
print('tensorflow:', getattr(tf, '__version__', 'not installed'))
print('torch:', getattr(torch, '__version__', 'not installed'))
print('xgboost:', getattr(xgb, '__version__', 'not installed'))
print('lightgbm:', getattr(lgb, '__version__', 'not installed'))

# %%
# Plotting/pandas defaults
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (8, 5)
pd.options.display.max_columns = 100
pd.options.display.width = 120
print('Display and plotting defaults set.')

# %%
# Load a small smoke-test dataset (Iris)
from sklearn.datasets import load_iris
data = load_iris(as_frame=True)
df = data.frame
print('Loaded iris — shape:', df.shape)
df.head()

# %%
# Basic preprocessing and train/test split
X = df.drop(columns=['target'])
y = df['target']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=SEED)
print('Train / test shapes:', X_train.shape, X_test.shape)

# %%
# Quick sklearn pipeline: train & evaluate a classifier
from sklearn.pipeline import make_pipeline
pipe = make_pipeline(StandardScaler(), LogisticRegression(max_iter=200, random_state=SEED))
pipe.fit(X_train, y_train)
preds = pipe.predict(X_test)
print('Accuracy:', accuracy_score(y_test, preds))
print(classification_report(y_test, preds))

# %% [markdown]
# ## Next steps / notes
# - If a package is missing, run `%pip install <package>` in a new cell.
# - This notebook is intended as a starting point. You can extend it with Keras/PyTorch examples, model saving, or more advanced preprocessing.
